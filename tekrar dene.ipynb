# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier()
from sklearn.ensemble import RandomForestClassifier
r=RandomForestClassifier()

from sklearn.tree import DecisionTreeClassifier
d=DecisionTreeClassifier()

from sklearn.linear_model import LogisticRegression
log=LogisticRegression()

from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
g=GaussianNB()
b=BernoulliNB()

from sklearn.neighbors import KNeighborsClassifier
k=KNeighborsClassifier()

from xgboost import XGBClassifier
xgbc=XGBClassifier()

# %%
df=pd.read_csv("LoansTrainingSet.csv")
df
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                      Loan ID  \
# 0       000025bb-5694-4cff-b17d-192b1a98ba44
# 1       00002c49-3a29-4bd4-8f67-c8f8fbc1048c
# 2       00002d89-27f3-409b-aa76-90834f359a65
# 3       00005222-b4d8-45a4-ad8c-186057e24233
# 4       0000757f-a121-41ed-b17b-162e76647c1f
# ...                                      ...
# 256979  fffef5b7-be99-4666-ac70-2a397d2ee435
# 256980  ffffca93-aa8c-4123-b8ff-7852f6df889a
# 256981  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256982  ffffcb2e-e48e-4d2c-a0d6-ed6bce5bfdbe
# 256983  ffffe32e-ed17-459f-9cfd-7b9ee7972933
#
#                                  Customer ID  Loan Status  \
# 0       5ebc8bb1-5eb9-4404-b11b-a6eebc401a19   Fully Paid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Loan ID                       256984 non-null  object
#  1   Customer ID                   256984 non-null  object
#  2   Loan Status                   256984 non-null  object
#  3   Current Loan Amount           256984 non-null  int64
#  4   Term                          256984 non-null  object
#  5   Credit Score                  195308 non-null  float64
#  6   Years in current job          245508 non-null  object
#  7   Home Ownership                256984 non-null  object
#  8   Annual Income                 195308 non-null  float64
#  9   Purpose                       256984 non-null  object
#  10  Monthly Debt                  256984 non-null  object
#  11  Years of Credit History       256984 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Current Loan Amount   Credit Score  Annual Income  \
# count         2.569840e+05  195308.000000   1.953080e+05
# mean          1.371331e+07    1251.116099   7.195272e+04
# std           3.438131e+07    1762.016848   5.887757e+04
# min           5.050000e+02     585.000000   0.000000e+00
# 25%           8.299000e+03     714.000000   4.432100e+04
# 50%           1.429800e+04     733.000000   6.124200e+04
# 75%           2.436700e+04     744.000000   8.646200e+04
# max           1.000000e+08    7510.000000   8.713547e+06
#
#        Years of Credit History  Months since last delinquent  \
# count            256984.000000                 116601.000000
# mean                 18.290195                     34.881450
# std                   7.075747                     21.854165
# min                   3.400000                      0.000000
# 25%                  13.500000                     16.000000
# 50%                  17.000000                     32.000000
# ...

# %%
df=df.drop(["Loan ID","Customer ID"],axis=1)

# %%
for col in df:
    print(col,df[col].isnull().sum())
# Out:
# Loan Status 0
# Current Loan Amount 0
# Term 0
# Credit Score 61676
# Years in current job 11476
# Home Ownership 0
# Annual Income 61676
# Purpose 0
# Monthly Debt 0
# Years of Credit History 0
# Months since last delinquent 140383
# Number of Open Accounts 0
# Number of Credit Problems 0
# Current Credit Balance 0
# Maximum Open Credit 0
# Bankruptcies 529
# Tax Liens 23

# %%
non_null=df[['Current Loan Amount', 'Term', 'Credit Score',
       'Home Ownership','Purpose',
       'Monthly Debt', 'Years of Credit History',
        'Number of 200Open Accounts',
       'Number of Credit Problems', 'Current Credit Balance',
       'Maximum Open Credit']]

# %%
non_null.info() #credit score'u regression ile tahmin edeceğiz.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Current Loan Amount        256984 non-null  int64
#  1   Term                       256984 non-null  object
#  2   Credit Score               195308 non-null  float64
#  3   Home Ownership             256984 non-null  object
#  4   Purpose                    256984 non-null  object
#  5   Monthly Debt               256984 non-null  object
#  6   Years of Credit History    256984 non-null  float64
#  7   Number of Open Accounts    256984 non-null  int64
#  8   Number of Credit Problems  256984 non-null  int64
#  9   Current Credit Balance     256984 non-null  int64
#  10  Maximum Open Credit        256984 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 21.6+ MB

# %%
for col in df:
    print(col,df[col].nunique())
# Out:
# Loan Status 2
# Current Loan Amount 27347
# Term 2
# Credit Score 334
# Years in current job 11
# Home Ownership 4
# Annual Income 60558
# Purpose 10
# Monthly Debt 129115
# Years of Credit History 541
# Months since last delinquent 131
# Number of Open Accounts 59
# Number of Credit Problems 12
# Current Credit Balance 45704
# Maximum Open Credit 87188
# Bankruptcies 8
# Tax Liens 12

# %%
non_null["Monthly Debt"]=non_null["Monthly Debt"].str.extract('(\d+)').astype(float)
# Out:
# <ipython-input-9-4145933aaa25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_null["Monthly Debt"]=non_null["Monthly Debt"].str.extract('(\d+)').astype(float)

# %%
non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Current Loan Amount        256984 non-null  int64
#  1   Term                       256984 non-null  object
#  2   Credit Score               195308 non-null  float64
#  3   Home Ownership             256984 non-null  object
#  4   Purpose                    256984 non-null  object
#  5   Monthly Debt               256984 non-null  float64
#  6   Years of Credit History    256984 non-null  float64
#  7   Number of Open Accounts    256984 non-null  int64
#  8   Number of Credit Problems  256984 non-null  int64
#  9   Current Credit Balance     256984 non-null  int64
#  10  Maximum Open Credit        256984 non-null  object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 21.6+ MB

# %%
non_null["Maximum Open Credit"]=non_null["Maximum Open Credit"].replace({'#VALUE!':"0"})
# Out:
# <ipython-input-11-30685bbfa0fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_null["Maximum Open Credit"]=non_null["Maximum Open Credit"].replace({'#VALUE!':"0"})

# %%
non_null["Maximum Open Credit"]=non_null["Maximum Open Credit"].astype(float)
# Out:
# <ipython-input-12-3fb8363a46fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_null["Maximum Open Credit"]=non_null["Maximum Open Credit"].astype(float)

# %%
non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Current Loan Amount        256984 non-null  int64
#  1   Term                       256984 non-null  object
#  2   Credit Score               195308 non-null  float64
#  3   Home Ownership             256984 non-null  object
#  4   Purpose                    256984 non-null  object
#  5   Monthly Debt               256984 non-null  float64
#  6   Years of Credit History    256984 non-null  float64
#  7   Number of Open Accounts    256984 non-null  int64
#  8   Number of Credit Problems  256984 non-null  int64
#  9   Current Credit Balance     256984 non-null  int64
#  10  Maximum Open Credit        256984 non-null  float64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 21.6+ MB

# %%
non_null=pd.get_dummies(non_null,drop_first=True)

# %%
dolu=non_null[non_null['Credit Score'].notnull()] #we seperate the df into two. If survived value is not null then it becomes our train set  
bos=non_null[non_null['Credit Score'].isnull()]
dolu.head()
y=dolu['Credit Score'] #dolu dataframes Survived value is our y_train
x=dolu.drop(['Credit Score'],axis=1)
bos=pd.get_dummies(bos,drop_first=True) 
bos.shape
# Out:
# (61676, 21)

# %%
dolu.head()
# Out:
#    Current Loan Amount  Credit Score  Monthly Debt  Years of Credit History  \
# 0                11520         741.0         584.0                     12.3
# 1                 3441         734.0           1.0                     26.3
# 2                21029         747.0           1.0                     28.8
# 3                18743         747.0         751.0                     26.2
# 4                11731         746.0         355.0                     11.5
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                       10                          0                    6760
# 1                       17                          0                    6262
# 2                        5                          0                   20967
# 3                        9                          0                   22529
# 4                       12                          0                   17391
#
# ...

# %%
y=dolu['Credit Score'] #dolu dataframes Survived value is our y_train
x=dolu.drop(['Credit Score'],axis=1)

# %%
bos=pd.get_dummies(bos,drop_first=True) 
bos.shape
# Out:
# (61676, 21)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LinearRegression
LR=LinearRegression()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge,Lasso
R=Ridge()
L=Lasso()

from sklearn.linear_model import ElasticNet
E= ElasticNet(l1_ratio=.8)

from sklearn.ensemble import GradientBoostingRegressor
GBR= GradientBoostingRegressor()

from sklearn.tree import ExtraTreeRegressor
ETR = ExtraTreeRegressor()

from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
models=[LR,R,L,E,GBR,ETR]
def model(models,x,y):
    row_list=[]
    for i in range(len(models)):
        model=models[i]
        #modelname=['gbc', 'd', 'k', 'g','b','r','log'] #names of models we will use them as indexes
        model.fit(x,y)
        tahmin=model.predict(x)
        
        #r2_score(y_test,y_pred_ridge)
        #creating a dictionary to calculate scores for each model in the models list
        data={'r2_score':(mean_squared_error(y,tahmin))**0.5,
              'mean_squared_error':r2_score(y,tahmin),
             }
        
        row_list.append(data) #appending the dictionary to a list to turn it into a dataframe
        
        #printing the scores
       # print(accuracy_score(y,tahmin),precision_score(y,tahmin),recall_score(y,tahmin),f1_score(y,tahmin))
        #print(confusion_matrix(y,tahmin))
       # print(classification_report(y,tahmin))
    
    #adding each element of row_list to the df dataframe (each element of row_list is a row of df )
    df = pd.DataFrame(row_list, index =['LR', 'R', 'L', 'E','GBR','ETR']) 
    return df

# %%
model(models,x,y)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.85327e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
#         r2_score  mean_squared_error
# LR   1740.724548            0.024017
# R    1740.724550            0.024017
# L    1740.950747            0.023763
# E    1741.985760            0.022602
# GBR  1734.147659            0.031378
# ETR   965.493690            0.699751

# %%
del bos['Credit Score']

# %%
tahmin=ETR.predict(bos)
len(tahmin)
# Out:
# 61676

# %%
bos['Credit Score']=tahmin

# %%
non_null['Credit Score']=non_null['Credit Score'].fillna(bos['Credit Score'])

# %%
non_null
# Out:
#         Current Loan Amount  Credit Score  Monthly Debt  \
# 0                     11520         741.0         584.0
# 1                      3441         734.0           1.0
# 2                     21029         747.0           1.0
# 3                     18743         747.0         751.0
# 4                     11731         746.0         355.0
# ...                     ...           ...           ...
# 256979                 3911         738.0           1.0
# 256980                 5078         737.0           1.0
# 256981                12116        7460.0         297.0
# 256982                12116         746.0         297.0
# 256983                27902         678.0           2.0
#
#         Years of Credit History  Number of Open Accounts  \
# 0                          12.3                       10
# 1                          26.3                       17
# 2                          28.8                        5
# 3                          26.2                        9
# ...

# %%
non_null["Years in current job"]=df["Years in current job"]

# %%
non_null["Years in current job"]=non_null["Years in current job"].str.extract('(\d+)').astype(float)

# %%
non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Current Loan Amount           256984 non-null  int64
#  1   Credit Score                  256984 non-null  float64
#  2   Monthly Debt                  256984 non-null  float64
#  3   Years of Credit History       256984 non-null  float64
#  4   Number of Open Accounts       256984 non-null  int64
#  5   Number of Credit Problems     256984 non-null  int64
#  6   Current Credit Balance        256984 non-null  int64
#  7   Maximum Open Credit           256984 non-null  float64
#  8   Term_Short Term               256984 non-null  uint8
#  9   Home Ownership_Home Mortgage  256984 non-null  uint8
#  10  Home Ownership_Own Home       256984 non-null  uint8
#  11  Home Ownership_Rent           256984 non-null  uint8
# ...

# %%
dolu=non_null[non_null["Years in current job"].notnull()] #we seperate the df into two. If survived value is not null then it becomes our train set  
bos=non_null[non_null["Years in current job"].isnull()]
dolu.head()
y=dolu["Years in current job"] #dolu dataframes Survived value is our y_train
x=dolu.drop(["Years in current job"],axis=1)
bos=pd.get_dummies(bos,drop_first=True) 
bos.shape
# Out:
# (11476, 22)

# %%
        #modelname=['gbc', 'd', 'k', 'g','b','r','log'] #names of models we will use them as indexes
xgbc.fit(x,y)
tahmin=xgbc.predict(x)
accuracy_score(y,tahmin)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\xgboost\sklearn.py:892: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:44:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.39056161102693193

# %%
non_null["Years in current job"].nunique()
# Out:
# 10

# %%
del bos["Years in current job"]

tahmin=xgbc.predict(bos)
len(tahmin)

bos["Years in current job"]=tahmin

non_null["Years in current job"]=non_null["Years in current job"].fillna(bos["Years in current job"])

non_null
# Out:
#         Current Loan Amount  Credit Score  Monthly Debt  \
# 0                     11520         741.0         584.0
# 1                      3441         734.0           1.0
# 2                     21029         747.0           1.0
# 3                     18743         747.0         751.0
# 4                     11731         746.0         355.0
# ...                     ...           ...           ...
# 256979                 3911         738.0           1.0
# 256980                 5078         737.0           1.0
# 256981                12116        7460.0         297.0
# 256982                12116         746.0         297.0
# 256983                27902         678.0           2.0
#
#         Years of Credit History  Number of Open Accounts  \
# 0                          12.3                       10
# 1                          26.3                       17
# 2                          28.8                        5
# 3                          26.2                        9
# ...

# %%
non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Current Loan Amount           256984 non-null  int64
#  1   Credit Score                  256984 non-null  float64
#  2   Monthly Debt                  256984 non-null  float64
#  3   Years of Credit History       256984 non-null  float64
#  4   Number of Open Accounts       256984 non-null  int64
#  5   Number of Credit Problems     256984 non-null  int64
#  6   Current Credit Balance        256984 non-null  int64
#  7   Maximum Open Credit           256984 non-null  float64
#  8   Term_Short Term               256984 non-null  uint8
#  9   Home Ownership_Home Mortgage  256984 non-null  uint8
#  10  Home Ownership_Own Home       256984 non-null  uint8
#  11  Home Ownership_Rent           256984 non-null  uint8
# ...

# %%
non_null["Annual Income"]=df["Annual Income"]
dolu=non_null[non_null["Annual Income"].notnull()] #we seperate the df into two. If survived value is not null then it becomes our train set  
bos=non_null[non_null["Annual Income"].isnull()]
dolu.head()
y=dolu["Annual Income"] #dolu dataframes Survived value is our y_train
x=dolu.drop(["Annual Income"],axis=1)
bos=pd.get_dummies(bos,drop_first=True) 
bos.shape
# Out:
# (61676, 23)

# %%
model(models,x,y)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.85304e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 292306065361516.44, tolerance: 67704515128.85589
#   model = cd_fast.enet_coordinate_descent(
#          r2_score  mean_squared_error
# LR   54745.603187            0.135429
# R    54745.603631            0.135429
# L    54745.656622            0.135427
# E    54868.213611            0.131552
# GBR  50121.221657            0.275321
# ETR      0.000000            1.000000

# %%
del bos["Annual Income"]

tahmin=GBR.predict(bos)
len(tahmin)

bos["Annual Income"]=tahmin

non_null["Annual Income"]=non_null["Annual Income"].fillna(bos["Annual Income"])

non_null
# Out:
#         Current Loan Amount  Credit Score  Monthly Debt  \
# 0                     11520         741.0         584.0
# 1                      3441         734.0           1.0
# 2                     21029         747.0           1.0
# 3                     18743         747.0         751.0
# 4                     11731         746.0         355.0
# ...                     ...           ...           ...
# 256979                 3911         738.0           1.0
# 256980                 5078         737.0           1.0
# 256981                12116        7460.0         297.0
# 256982                12116         746.0         297.0
# 256983                27902         678.0           2.0
#
#         Years of Credit History  Number of Open Accounts  \
# 0                          12.3                       10
# 1                          26.3                       17
# 2                          28.8                        5
# 3                          26.2                        9
# ...

# %%
non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Current Loan Amount           256984 non-null  int64
#  1   Credit Score                  256984 non-null  float64
#  2   Monthly Debt                  256984 non-null  float64
#  3   Years of Credit History       256984 non-null  float64
#  4   Number of Open Accounts       256984 non-null  int64
#  5   Number of Credit Problems     256984 non-null  int64
#  6   Current Credit Balance        256984 non-null  int64
#  7   Maximum Open Credit           256984 non-null  float64
#  8   Term_Short Term               256984 non-null  uint8
#  9   Home Ownership_Home Mortgage  256984 non-null  uint8
#  10  Home Ownership_Own Home       256984 non-null  uint8
#  11  Home Ownership_Rent           256984 non-null  uint8
# ...

# %%
non_null["Months since last delinquent"]=df["Months since last delinquent"]
dolu=non_null[non_null["Months since last delinquent"].notnull()] #we seperate the df into two. If survived value is not null then it becomes our train set  
bos=non_null[non_null["Months since last delinquent"].isnull()]
dolu.head()
y=dolu["Months since last delinquent"] #dolu dataframes Survived value is our y_train
x=dolu.drop(["Months since last delinquent"],axis=1)
bos=pd.get_dummies(bos,drop_first=True) 
bos.shape
# Out:
# (140383, 24)

# %%
model(models,x,y)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.61619e-19): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
#       r2_score  mean_squared_error
# LR   21.684889            0.015423
# R    21.684889            0.015423
# L    21.794150            0.005476
# E    21.776616            0.007076
# GBR  21.349625            0.045632
# ETR   0.000000            1.000000

# %%
del bos["Months since last delinquent"]

tahmin=GBR.predict(bos)
len(tahmin)

bos["Months since last delinquent"]=tahmin

non_null["Months since last delinquent"]=non_null["Months since last delinquent"].fillna(bos["Months since last delinquent"])

non_null
# Out:
#         Current Loan Amount  Credit Score  Monthly Debt  \
# 0                     11520         741.0         584.0
# 1                      3441         734.0           1.0
# 2                     21029         747.0           1.0
# 3                     18743         747.0         751.0
# 4                     11731         746.0         355.0
# ...                     ...           ...           ...
# 256979                 3911         738.0           1.0
# 256980                 5078         737.0           1.0
# 256981                12116        7460.0         297.0
# 256982                12116         746.0         297.0
# 256983                27902         678.0           2.0
#
#         Years of Credit History  Number of Open Accounts  \
# 0                          12.3                       10
# 1                          26.3                       17
# 2                          28.8                        5
# 3                          26.2                        9
# ...

# %%
non_null['Bankruptcies']=df['Bankruptcies']
non_null['Tax Liens']=df['Tax Liens']
non_null['Bankruptcies'].fillna((non_null['Bankruptcies'].mean()), inplace=True)
non_null['Tax Liens'].fillna((non_null['Tax Liens'].mean()), inplace=True)

# %%
non_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256984 entries, 0 to 256983
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Current Loan Amount           256984 non-null  int64
#  1   Credit Score                  256984 non-null  float64
#  2   Monthly Debt                  256984 non-null  float64
#  3   Years of Credit History       256984 non-null  float64
#  4   Number of Open Accounts       256984 non-null  int64
#  5   Number of Credit Problems     256984 non-null  int64
#  6   Current Credit Balance        256984 non-null  int64
#  7   Maximum Open Credit           256984 non-null  float64
#  8   Term_Short Term               256984 non-null  uint8
#  9   Home Ownership_Home Mortgage  256984 non-null  uint8
#  10  Home Ownership_Own Home       256984 non-null  uint8
#  11  Home Ownership_Rent           256984 non-null  uint8
# ...

# %%
non_null=pd.get_dummies(non_null,drop_first=True)

# %%
non_null
# Out:
#         Current Loan Amount  Credit Score  Monthly Debt  \
# 0                     11520         741.0         584.0
# 1                      3441         734.0           1.0
# 2                     21029         747.0           1.0
# 3                     18743         747.0         751.0
# 4                     11731         746.0         355.0
# ...                     ...           ...           ...
# 256979                 3911         738.0           1.0
# 256980                 5078         737.0           1.0
# 256981                12116        7460.0         297.0
# 256982                12116         746.0         297.0
# 256983                27902         678.0           2.0
#
#         Years of Credit History  Number of Open Accounts  \
# 0                          12.3                       10
# 1                          26.3                       17
# 2                          28.8                        5
# 3                          26.2                        9
# ...

# %%
non_null['Loan Status']=df['Loan Status']

# %%
y=non_null['Loan Status'].replace({"Fully Paid":0,"Charged Off":1})

# %%
x=non_null.drop('Loan Status',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test =train_test_split(x,y,test_size=0.30, random_state=13)

# %%
x
# Out:
#         Current Loan Amount  Credit Score  Monthly Debt  \
# 0                     11520         741.0         584.0
# 1                      3441         734.0           1.0
# 2                     21029         747.0           1.0
# 3                     18743         747.0         751.0
# 4                     11731         746.0         355.0
# ...                     ...           ...           ...
# 256979                 3911         738.0           1.0
# 256980                 5078         737.0           1.0
# 256981                12116        7460.0         297.0
# 256982                12116         746.0         297.0
# 256983                27902         678.0           2.0
#
#         Years of Credit History  Number of Open Accounts  \
# 0                          12.3                       10
# 1                          26.3                       17
# 2                          28.8                        5
# 3                          26.2                        9
# ...

# %%
model=gbc

# %%
model.fit(x_train,y_train)
tahmin=model.predict(x_test)

# %%
accuracy_score(y_test,tahmin),precision_score(y_test,tahmin),recall_score(y_test,tahmin),f1_score(y_test,tahmin)
# Out:
# (0.770857113209505, 0.754037555057569, 0.40254114929252094, 0.5248776289602496)
